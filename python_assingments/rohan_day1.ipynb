# %% [markdown]
# List Operations

# %%
lst1 = ["rohan",20,10]
lst2 = ["shree",45,20]

# %%
print(lst1)
lst2
# Out:
# ['rohan', 20, 10]
# ['shree', 45, 20]

# %%
print(lst1.index(20))
lst1.index("rohan")
# Out:
# 1
# 0

# %%
lst1.append("sam")

# %%
print(lst1)
lst2
# Out:
# ['rohan', 20, 10, 'Patil', 'Patil', 'sam']
# ['shree', 45, 20, 'Kale']

# %%
lst2.append("")
print(lst1)
# Out:
# ['rohan', 20, 10, 'sam']

# %%
print(lst2)
lst1.remove("Patil")
# Out:
# ['shree', 45, 20, 'Kale', 'men', 'men', 'men', '']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 print(lst2)
# ----> 2 lst1.remove("Patil")
#
# ValueError: list.remove(x): x not in list

# %%
ls3 = lst1.copy()
print(id(ls3))
print(id(lst1))
# Out:
# 140504657391872
# 140505094208512

# %%
lst2.count('men')
# Out:
# 3

# %%
lst1.extend(lst2)

# %%
lst1
# Out:
# ['rohan', 20, 10]

# %%
lst1.index('rohan')
# Out:
# 0

# %%
lst1.insert(4,'map')

# %%
lst1
# Out:
# ['rohan', 20, 10]

# %%
lst1.pop(3)
# Out:
# 'map'

# %%
lst1
# Out:
# ['rohan', 20, 10]

# %%
lst1.reverse()
lst1
# Out:
# [10, 20, 'rohan']

# %%
lst3 = [1,5,2,7,3]

# %%
lst3.sort()

# %%
print(lst3)
# Out:
# [1, 2, 3, 5, 7]

# %% [markdown]
# Tuple Operations

# %%
tp = (10,20,30,40,50,20)
tp
# Out:
# (10, 20, 30, 40, 50, 20)

# %%
tp.count(20)
# Out:
# 2

# %%
tp.index(20)
# Out:
# 1

# %% [markdown]
# Set Operations

# %%
st = {'sap',20,30}
st
# Out:
# {20, 30, 'sap'}

# %%
st.add("hx")

# %%
st
# Out:
# {20, 30, 'hx', 'sap'}

# %%
st.copy()
# Out:
# {20, 30, 'hx', 'sap'}

# %%
st2 = {'spark',23,45,20}
st2
# Out:
# {20, 23, 45, 'spark'}

# %%
st2.difference(st)
# Out:
# {20, 23, 45, 'spark'}

# %%
st2.difference_update(st)
st
# Out:
# {30, 'hx', 'sap'}

# %%
st2.discard(23)

# %%
st.add("spark")

# %%
st.intersection(st2)
# Out:
# {'spark'}

# %%
st.isdisjoint(st2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 st.isdisjoint(st2)
# ----> 2 st + st2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
st.issubset(st2)
# Out:
# False

# %%
st.issuperset(st2)
# Out:
# False

# %%
st3 ={1,2,3}
st3.pop()
# Out:
# 1

# %%
st3
# Out:
# {1}

# %%
st4 = {1,2,3,4,5,6}
st4
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
st4.remove(6)
st4
# Out:
# {1, 2, 3, 4, 5}

# %%
st3.symmetric_difference(st4)
# Out:
# {1, 2, 3, 4, 5}

# %%
st3.symmetric_difference_update(st4)

# %%
st3.union(st2)
# Out:
# {2, 20, 3, 45, 'spark'}

# %%
st3.update(st4)

# %%
st3
# Out:
# {1, 2, 20, 3, 30, 4, 5, 'hive', 'python'}

# %% [markdown]
# Dictionary Operations

# %%
dict = {"Name":"stark", "Degree":"endgame"}
dict
# Out:
# {'Name': 'stark', 'Degree': 'endgame'}

# %%
dict.get("Name")
# Out:
# 'stark'

# %%
dict.items()
lst = [lambda i , item=item : i + item[1] for item  in dict.items() ]
lst
# Out:
# [<function __main__.<lambda>(i, item=('Name', 'stark'))>,
#  <function __main__.<lambda>(i, item=('Degree', 'endgame'))>]

# %%
dict.keys()
# Out:
# dict_keys(['Name', 'Degree'])

# %%
dict.popitem()
# Out:
# ('Degree', 'B.tech')

# %%
dict
# Out:
# {'Name': 'Tanmayee'}

# %%
dict.copy()  #shallow copy and Deep copy
# Out:
# {'Name': 'Tanmayee'}

# %%
dict.fromkeys("Name")
# Out:
# {'N': None, 'a': None, 'm': None, 'e': None}

# %%
dict2 ={"Degree":"B.E","Year":2025}
dict2
# Out:
# {'Degree': 'B.E', 'Year': 2025}

# %%
dict.update(dict2)

# %%
dict
# Out:
# {'Name': 'Tanmayee', 'Degree': 'B.tech', 'Year': 2025}

# %%
dict.values()
# Out:
# dict_values(['stark', 'B.E', 2025])

# %% [markdown]
# String Operations

# %%
str = 'rohan'
str2 = 'men'

# %%
print(str)
print(str2)
# Out:
# rohan
# men

# %%
str.upper()
# Out:
# 'ROHAN'

# %%
str.capitalize()
# Out:
# 'Rohan'

# %%
str2.casefold()
# Out:
# 'men'

# %%
str2.count("Tanmayee")
# Out:
# 0

# %%
str2.endswith('j')
# Out:
# False

# %%
str2.split()
# Out:
# ['men']

# %%
str2.upper()
# Out:
# 'MEN'

# %%
str2.swapcase()
# Out:
# 'MEN'

# %%
str2.startswith('p')
# Out:
# False

# %%
str2.istitle()
# Out:
# False
