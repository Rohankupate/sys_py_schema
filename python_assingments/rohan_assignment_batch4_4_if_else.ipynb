# %% [markdown]
# ### 1. Write a program to check if a number is positive.

# %%
# Out:
# your number -15 is positive

# %% [markdown]
# ### 2. Check if a number is even or odd.

# %%
# Out:
# your number 16 is even

# %% [markdown]
# ### 3. Check if a person is eligible to vote (age >= 18).

# %%
# Out:
# hey mine you need 3 more years to eligible to voat

# %% [markdown]
# ### 4. Check if a number is greater than 100.

# %% [markdown]
# ### 5. Print “Adult” if age > 18 else print “Child”.

# %% [markdown]
# ### 6. Check if two numbers are equal.

# %% [markdown]
# ### 7. Check if a number is divisible by 5.

# %% [markdown]
# ### 8. Check if a string is “hello”.

# %% [markdown]
# ### 9. Print the larger of two numbers.

# %% [markdown]
# ### 10. Check if a number is negative

# %% [markdown]
# ### 11. Check if a number is positive, negative, or zero.

# %% [markdown]
# ### 12. Check if a year is a leap year.

# %% [markdown]
# ### 13. Check if a character is a vowel or consonant.

# %% [markdown]
# ### 14. Print the greatest of three numbers.

# %% [markdown]
# ### 15. Check if a password length is strong (>= 8).

# %% [markdown]
# ### 16. Check if a number lies between 10 and 50.

# %% [markdown]
# ### 17. Print the grade of a student (A, B, C, D, F) based on marks.

# %% [markdown]
# ### 18. Check if a number is divisible by both 2 and 3.

# %% [markdown]
# ### 19. Check if a person’s age falls into categories: child, teen, adult, senior.

# %% [markdown]
# ### 20. Check if a character is uppercase or lowercase.

# %% [markdown]
# ### 21. Check if a number is a multiple of 10.

# %% [markdown]
# ### 22. Compare two numbers and print “greater”, “smaller”, or “equal”.

# %% [markdown]
# ### 23. Check if a triangle is equilateral, isosceles, or scalene.

# %% [markdown]
# ### 24. Check if a string contains the word “python”.

# %% [markdown]
# ### 25. Check if a list has more than 5 elements.

# %% [markdown]
# ### 26. Check if temperature is cold (<15), warm (15–30), or hot (>30).

# %% [markdown]
# ### 27. Check if a student passed (marks >= 40) else fail.

# %% [markdown]
# ### 28. Check if a number ends with digit 7.

# %% [markdown]
# ### 29. Check if the first character of a string is a vowel.

# %% [markdown]
# ### 30. Check if a number is within 1 to 100, else print “out of range

# %% [markdown]
# ### 31. Check if a number is prime using if-else (simple logic allowed).

# %% [markdown]
# ### 32. Check if the last digit of a number is even or odd.

# %% [markdown]
# ### 33. Check if the input is an integer or not (using string checks).

# %% [markdown]
# ### 34. Check if three angles can form a valid triangle.

# %% [markdown]
# ### 35. Check if two strings are anagrams (simple: check sorted equality).

# %% [markdown]
# ### 36. Determine the type of triangle using sides: acute, right, obtuse.

# %% [markdown]
# ### 37. Check if a string is palindrome (case insensitive).

# %% [markdown]
# ### 38. Check if the first and last characters of a string are same.

# %% [markdown]
# ### 39. Check if the sum of digits of a number is divisible by 3.

# %% [markdown]
# ### 40. Check if a number is Armstrong (3-digit).

# %% [markdown]
# ### 41. Check if a number has exactly 3 digits.

# %% [markdown]
# ### 42. Check if a number is perfect (sum of factors equals number).

# %% [markdown]
# ### 43. Compare lengths of two strings and print which is longer.

# %% [markdown]
# ### 44. Check if a list contains duplicates.

# %% [markdown]
# ### 45. Check if a number is both prime AND even (only possible is 2).

# %% [markdown]
# ### 46. Print “YES” if any of the two numbers is zero else print “NO”.

# %% [markdown]
# ### 47. Check if two numbers have the same last digit.

# %% [markdown]
# ### 48. Check if a password contains both letters and digits.

# %% [markdown]
# ### 49. Check if a number is “lucky”: sum of first two digits equals last two digits.

# %% [markdown]
# ### 50. Check if the absolute difference between two numbers is less than 10

# %% [markdown]
# ### 51. Write a program to check if a variable is an integer using isinstance().

# %% [markdown]
# ### 52. Check if a given input is a string using isinstance().

# %% [markdown]
# ### 53. Check if a variable is a float and print “Float value found”.

# %% [markdown]
# ### 54. Check if a variable is a list; if yes, print its length.

# %% [markdown]
# ### 55. Write a program to check if a variable is a tuple; if yes, print the first element.

# %% [markdown]
# ### 56. Check if a variable is a dictionary; if yes, print all keys.

# %% [markdown]
# ### 57. Check if a variable is a set; if yes, print the number of elements.

# %% [markdown]
# ### 58. Check if a variable is a boolean and print “True/False detected”.

# %% [markdown]
# ### 59. Write a program to check if a variable is either int OR float (number check).

# %% [markdown]
# ### 60. Check if a variable is NOT a list (using not isinstance()), and print: “Not a list”.

# %% [markdown]
# #### finf number off or not

# %%
import math

def issprime(n):
    if n == 2 :
        return True
    if n== 1 or n==0:
        return False 
#     print("sqr root of "  ,n , " is " , int(math.sqrt(n))+1)
    for i in range(2 , int(math.sqrt(n))+1):
#         print(f'value of n is {n} and valuse of i is {i} and  n%i==0 result is {n%i==0}' )
        if n%i==0:
            return False
    return True

# %%
issprime(15)
# Out:
# sqr root of  15  is  4
# value of n is 15 and valuse of i is 2 and  n%i==0 result is False
# value of n is 15 and valuse of i is 3 and  n%i==0 result is True
# False

# %%
for i in range (100):
    if issprime(i) :
        print(f'{i} is valid prime number')
    else :
        print(f'{i} is not prime number')
# Out:
# 0 is not prime number
# 1 is not prime number
# 2 is valid prime number
# 3 is valid prime number
# 4 is not prime number
# 5 is valid prime number
# 6 is not prime number
# 7 is valid prime number
# 8 is not prime number
# 9 is not prime number
# 10 is not prime number
# 11 is valid prime number
# 12 is not prime number
# 13 is valid prime number
# 14 is not prime number
# 15 is not prime number
# 16 is not prime number
# 17 is valid prime number
# 18 is not prime number
# 19 is valid prime number
# 20 is not prime number
# 21 is not prime number
# 22 is not prime number
# 23 is valid prime number
# 24 is not prime number
# 25 is not prime number
# 26 is not prime number
# 27 is not prime number
# 28 is not prime number
# 29 is valid prime number
# 30 is not prime number
# 31 is valid prime number
# 32 is not prime number
# 33 is not prime number
# 34 is not prime number
# 35 is not prime number
# 36 is not prime number
# 37 is valid prime number
# 38 is not prime number
# 39 is not prime number
# 40 is not prime number
# 41 is valid prime number
# 42 is not prime number
# 43 is valid prime number
# 44 is not prime number
# 45 is not prime number
# 46 is not prime number
# 47 is valid prime number
# 48 is not prime number
# 49 is not prime number
# 50 is not prime number
# 51 is not prime number
# 52 is not prime number
# 53 is valid prime number
# 54 is not prime number
# 55 is not prime number
# 56 is not prime number
# 57 is not prime number
# 58 is not prime number
# 59 is valid prime number
# 60 is not prime number
# 61 is valid prime number
# 62 is not prime number
# 63 is not prime number
# 64 is not prime number
# 65 is not prime number
# 66 is not prime number
# 67 is valid prime number
# 68 is not prime number
# 69 is not prime number
# 70 is not prime number
# 71 is valid prime number
# 72 is not prime number
# 73 is valid prime number
# 74 is not prime number
# 75 is not prime number
# 76 is not prime number
# 77 is not prime number
# 78 is not prime number
# 79 is valid prime number
# 80 is not prime number
# 81 is not prime number
# 82 is not prime number
# 83 is valid prime number
# 84 is not prime number
# 85 is not prime number
# 86 is not prime number
# 87 is not prime number
# 88 is not prime number
# 89 is valid prime number
# 90 is not prime number
# 91 is not prime number
# 92 is not prime number
# 93 is not prime number
# 94 is not prime number
# 95 is not prime number
# 96 is not prime number
# 97 is valid prime number
# 98 is not prime number
# 99 is not prime number

# %%
listt=[1,2,3,4,5,4,3,2,3,4,5 ,11]
duplicated=[]

# %%
for i in listt:
    print(listt.count(i))
    if listt.count(i) > 1:
        duplicated.append(i)

duplicated
# Out:
# 1
# 2
# 3
# 3
# 2
# 3
# 3
# 2
# 3
# 3
# 2
# 1
# [2, 3, 4, 5, 4, 3, 2, 3, 4, 5]

# %%
tup=(1,2,3)
(a,b,c)= (tup)
print(a)
# Out:
# 1

# %%
*a,b,c= tup
print(a,b,c)
# Out:
#   Cell In[84], line 1
#     *(a,b,c)= tup
#     ^
# SyntaxError: starred assignment target must be in a list or tuple
